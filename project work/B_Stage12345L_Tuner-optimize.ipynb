# %%
import os

# %% [raw]
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import kerastuner
kerastuner.__version__
# Out:
# '1.0.2'

# %%
import glob
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from tensorflow.keras.utils import plot_model
from resnets_utils import *
from tensorflow.keras.initializers import he_normal
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

from tensorflow.keras import backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

from kerastuner.tuners import RandomSearch, Hyperband
from kerastuner.engine.hyperparameters import HyperParameters
# Out:
# /home/8p361-lecturer/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block as defined in Figure 3
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)


    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = he_normal(seed=None))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)


    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1',
                        kernel_initializer = he_normal(seed=None))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    
    return X

# %%
def ResNet(input_shape=(96, 96, 3), classes=1):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)

    # Stage 1
    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=he_normal(seed=None))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f=3, filters=[128,128,512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128,128,512], stage=3, block='d')
    X = identity_block(X, 3, [128,128,512], stage=3, block='e')
    X = identity_block(X, 3, [128,128,512], stage=3, block='f')
    X = identity_block(X, 3, [128,128,512], stage=3, block='g')
    X = identity_block(X, 3, [128,128,512], stage=3, block='h')
    X = identity_block(X, 3, [128,128,512], stage=3, block='i')
    X = identity_block(X, 3, [128,128,512], stage=3, block='j')

    # Stage 4
    X = convolutional_block(X, f=3, filters=[256,256,1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256,256,1024], stage=4, block='k')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='l')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='m')
    
    # Stage 5
    X = convolutional_block(X, f=3, filters=[512,512,2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512,512,2048], stage=5, block='n')
    X = identity_block(X, 3, [512,512,2048], stage=5, block='o')
    X = identity_block(X, 3, [512,512,2048], stage=5, block='p')
    X = identity_block(X, 3, [512,512,2048], stage=5, block='q')
    

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D((2,2), name="avg_pool")(X)

    ### END CODE HERE ###

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='sigmoid', name='fc' + str(classes), kernel_initializer = he_normal(seed=None))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)
    
    model.compile(SGD(lr=1e-6, momentum=0.95), loss = 'binary_crossentropy', metrics=['accuracy'])

    return model

# %%
#model = ResNet50(input_shape = (96, 96, 3), classes = 1)

# %%
#model.compile(SGD(lr=0.001, momentum=0.95), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

########### insert hyperparameters ################
train_batch_size = 32
val_batch_size = 32
###################################################

base_dir = r'data'
test_dir = r'data\test'

# dataset parameters
TRAIN_PATH = os.path.join(base_dir, 'train')
VALID_PATH = os.path.join(base_dir, 'valid')
TEST_FILES = glob.glob(test_dir + '\*.tif')
RESCALING_FACTOR = 1./255
IMAGE_SIZE = 96

# instantiate data generators
datagen = ImageDataGenerator(rescale=RESCALING_FACTOR)

train_gen = datagen.flow_from_directory(TRAIN_PATH,
                                    target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                    batch_size=train_batch_size,
                                    class_mode='binary',
                                    shuffle=True)

val_gen = datagen.flow_from_directory(VALID_PATH,
                                    target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                    batch_size=val_batch_size,
                                    class_mode='binary',
                                    shuffle=False)

# form steps
train_steps = train_gen.n//train_gen.batch_size
val_steps = val_gen.n//val_gen.batch_size
# Out:
# Found 144000 images belonging to 2 classes.
# Found 16000 images belonging to 2 classes.

# %%
#tuner = Hyperband(
#    build_model,
#    overwrite=True,
#    objective='val_accuracy',
#    max_epochs = 15,
#    factor = 2,
#    directory = 'storage/ResnetTuner_L',
#    project_name='ResNet_Stage12345_L'
#)

# %%
#stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
#tuner.search(train_gen,
#             verbose=1, 
#             epochs=25,
#             batch_size=32,
#             steps_per_epoch=train_steps,
#             callbacks=[stop_early],
#            validation_steps=val_steps,
#             validation_data=val_gen)

# %%
model = ResNet()

# %%
#best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
#print(best_hps)

# %%
# save the model and weights
model_name = 'ResNet_Stage12345_L'
model_filepath = './' + 'storage' + '/' + model_name + '.json'
weights_filepath = './' + 'storage' + '/' + model_name + '_weights.hdf5'

# serialize model to JSON
model_json = model.to_json()
with open(model_filepath, 'w') as json_file:
    json_file.write(model_json) 
    
# define the model checkpoint and Tensorboard callbacks
checkpoint = ModelCheckpoint(weights_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
tensorboard = TensorBoard(os.path.join('logs', model_name))
callbacks_list = [checkpoint, tensorboard]

# fit model
history = model.fit(train_gen, 
          epochs = 25, 
          batch_size = 32, 
          steps_per_epoch=train_steps,
          validation_data=val_gen,
          validation_steps=val_steps,
          callbacks=callbacks_list)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/25
# 4500/4500 [==============================] - 526s 115ms/step - loss: 0.7341 - accuracy: 0.5595 - val_loss: 0.6965 - val_accuracy: 0.5934
#
# Epoch 00001: val_loss improved from inf to 0.69648, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 2/25
# 4500/4500 [==============================] - 506s 112ms/step - loss: 0.6798 - accuracy: 0.6108 - val_loss: 0.6300 - val_accuracy: 0.6591
#
# Epoch 00002: val_loss improved from 0.69648 to 0.63004, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 3/25
# 4500/4500 [==============================] - 505s 112ms/step - loss: 0.6297 - accuracy: 0.6650 - val_loss: 0.5919 - val_accuracy: 0.6991
#
# Epoch 00003: val_loss improved from 0.63004 to 0.59188, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 4/25
# 4500/4500 [==============================] - 506s 112ms/step - loss: 0.6026 - accuracy: 0.6921 - val_loss: 0.5710 - val_accuracy: 0.7186
#
# Epoch 00004: val_loss improved from 0.59188 to 0.57103, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 5/25
# 4500/4500 [==============================] - 504s 112ms/step - loss: 0.5809 - accuracy: 0.7143 - val_loss: 0.5472 - val_accuracy: 0.7358
#
# Epoch 00005: val_loss improved from 0.57103 to 0.54723, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 6/25
# 4500/4500 [==============================] - 506s 112ms/step - loss: 0.5663 - accuracy: 0.7264 - val_loss: 0.5460 - val_accuracy: 0.7367
#
# Epoch 00006: val_loss improved from 0.54723 to 0.54600, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 7/25
# 4500/4500 [==============================] - 507s 113ms/step - loss: 0.5591 - accuracy: 0.7314 - val_loss: 0.5427 - val_accuracy: 0.7421
#
# Epoch 00007: val_loss improved from 0.54600 to 0.54266, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 8/25
# 4500/4500 [==============================] - 505s 112ms/step - loss: 0.5608 - accuracy: 0.7296 - val_loss: 0.5493 - val_accuracy: 0.7357
#
# Epoch 00008: val_loss did not improve from 0.54266
# Epoch 9/25
# 4500/4500 [==============================] - 507s 113ms/step - loss: 0.5542 - accuracy: 0.7325 - val_loss: 0.5309 - val_accuracy: 0.7453
#
# Epoch 00009: val_loss improved from 0.54266 to 0.53085, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 10/25
# 4500/4500 [==============================] - 512s 114ms/step - loss: 0.5465 - accuracy: 0.7373 - val_loss: 0.5200 - val_accuracy: 0.7543
#
# Epoch 00010: val_loss improved from 0.53085 to 0.52000, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 11/25
# 4500/4500 [==============================] - 512s 114ms/step - loss: 0.5448 - accuracy: 0.7397 - val_loss: 0.5099 - val_accuracy: 0.7622
#
# Epoch 00011: val_loss improved from 0.52000 to 0.50989, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 12/25
# 4500/4500 [==============================] - 500s 111ms/step - loss: 0.5408 - accuracy: 0.7412 - val_loss: 0.5147 - val_accuracy: 0.7587
#
# Epoch 00012: val_loss did not improve from 0.50989
# Epoch 13/25
# 4500/4500 [==============================] - 494s 110ms/step - loss: 0.5389 - accuracy: 0.7418 - val_loss: 0.5104 - val_accuracy: 0.7586
#
# Epoch 00013: val_loss did not improve from 0.50989
# Epoch 14/25
# 4500/4500 [==============================] - 494s 110ms/step - loss: 0.5347 - accuracy: 0.7442 - val_loss: 0.5127 - val_accuracy: 0.7569
#
# Epoch 00014: val_loss did not improve from 0.50989
# Epoch 15/25
# 4500/4500 [==============================] - 497s 111ms/step - loss: 0.5319 - accuracy: 0.7448 - val_loss: 0.5068 - val_accuracy: 0.7650
#
# Epoch 00015: val_loss improved from 0.50989 to 0.50681, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 16/25
# 4500/4500 [==============================] - 496s 110ms/step - loss: 0.5261 - accuracy: 0.7509 - val_loss: 0.5043 - val_accuracy: 0.7639
#
# Epoch 00016: val_loss improved from 0.50681 to 0.50426, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 17/25
# 4500/4500 [==============================] - 492s 109ms/step - loss: 0.5272 - accuracy: 0.7482 - val_loss: 0.5012 - val_accuracy: 0.7694
#
# Epoch 00017: val_loss improved from 0.50426 to 0.50116, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 18/25
# 4500/4500 [==============================] - 495s 110ms/step - loss: 0.5192 - accuracy: 0.7549 - val_loss: 0.4995 - val_accuracy: 0.7626
#
# Epoch 00018: val_loss improved from 0.50116 to 0.49948, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 19/25
# 4500/4500 [==============================] - 496s 110ms/step - loss: 0.5217 - accuracy: 0.7516 - val_loss: 0.4990 - val_accuracy: 0.7679
#
# Epoch 00019: val_loss improved from 0.49948 to 0.49899, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 20/25
# 4500/4500 [==============================] - 460s 102ms/step - loss: 0.5202 - accuracy: 0.7526 - val_loss: 0.4967 - val_accuracy: 0.7681
#
# Epoch 00020: val_loss improved from 0.49899 to 0.49672, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 21/25
# 4500/4500 [==============================] - 459s 102ms/step - loss: 0.5154 - accuracy: 0.7569 - val_loss: 0.4943 - val_accuracy: 0.7712
#
# Epoch 00021: val_loss improved from 0.49672 to 0.49428, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 22/25
# 4500/4500 [==============================] - 484s 107ms/step - loss: 0.5182 - accuracy: 0.7531 - val_loss: 0.4922 - val_accuracy: 0.7714
#
# Epoch 00022: val_loss improved from 0.49428 to 0.49220, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Epoch 23/25
# 4500/4500 [==============================] - 486s 108ms/step - loss: 0.5160 - accuracy: 0.7542 - val_loss: 0.4945 - val_accuracy: 0.7688
#
# Epoch 00023: val_loss did not improve from 0.49220
# Epoch 24/25
# 4500/4500 [==============================] - 486s 108ms/step - loss: 0.5138 - accuracy: 0.7557 - val_loss: 0.4956 - val_accuracy: 0.7678
#
# Epoch 00024: val_loss did not improve from 0.49220
# Epoch 25/25
# 4500/4500 [==============================] - 485s 108ms/step - loss: 0.5095 - accuracy: 0.7587 - val_loss: 0.4898 - val_accuracy: 0.7699
#
# Epoch 00025: val_loss improved from 0.49220 to 0.48980, saving model to ./storage/ResNet_Stage12345_L_weights.hdf5
# Best epoch: 22

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 23, 23, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 23, 23, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 23, 23, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 23, 23, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 23, 23, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 23, 23, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 23, 23, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 23, 23, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 23, 23, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 23, 23, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 23, 23, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 23, 23, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 23, 23, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 23, 23, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 23, 23, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 23, 23, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 12, 12, 128)  32896       activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 12, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 12, 12, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 12, 12, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 12, 12, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 12, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 12, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 12, 12, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 12, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 12, 12, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3e_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3e_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           bn3e_branch2a[0][0]
# __________________________________________________________________________________________________
# res3e_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn3e_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           bn3e_branch2b[0][0]
# __________________________________________________________________________________________________
# res3e_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3e_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 12, 512)  0           bn3e_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3f_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3f_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           bn3f_branch2a[0][0]
# __________________________________________________________________________________________________
# res3f_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# bn3f_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           bn3f_branch2b[0][0]
# __________________________________________________________________________________________________
# res3f_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3f_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 512)  0           bn3f_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 12, 12, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3g_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3g_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3g_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 12, 128)  0           bn3g_branch2a[0][0]
# __________________________________________________________________________________________________
# res3g_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_22[0][0]
# __________________________________________________________________________________________________
# bn3g_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3g_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 12, 128)  0           bn3g_branch2b[0][0]
# __________________________________________________________________________________________________
# res3g_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_23[0][0]
# __________________________________________________________________________________________________
# bn3g_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3g_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 512)  0           bn3g_branch2c[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 12, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res3h_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_24[0][0]
# __________________________________________________________________________________________________
# bn3h_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3h_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 12, 128)  0           bn3h_branch2a[0][0]
# __________________________________________________________________________________________________
# res3h_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_25[0][0]
# __________________________________________________________________________________________________
# bn3h_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3h_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           bn3h_branch2b[0][0]
# __________________________________________________________________________________________________
# res3h_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_26[0][0]
# __________________________________________________________________________________________________
# bn3h_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3h_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 512)  0           bn3h_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 512)  0           add_8[0][0]
# __________________________________________________________________________________________________
# res3i_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_27[0][0]
# __________________________________________________________________________________________________
# bn3i_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3i_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           bn3i_branch2a[0][0]
# __________________________________________________________________________________________________
# res3i_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# bn3i_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3i_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           bn3i_branch2b[0][0]
# __________________________________________________________________________________________________
# res3i_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_29[0][0]
# __________________________________________________________________________________________________
# bn3i_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3i_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 512)  0           bn3i_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# res3j_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_30[0][0]
# __________________________________________________________________________________________________
# bn3j_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res3j_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 128)  0           bn3j_branch2a[0][0]
# __________________________________________________________________________________________________
# res3j_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_31[0][0]
# __________________________________________________________________________________________________
# bn3j_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res3j_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           bn3j_branch2b[0][0]
# __________________________________________________________________________________________________
# res3j_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_32[0][0]
# __________________________________________________________________________________________________
# bn3j_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res3j_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 512)  0           bn3j_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 6, 6, 256)    131328      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 6, 6, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 6, 6, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_35[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 6, 6, 1024)   525312      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 6, 6, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 6, 6, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 6, 6, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4k_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res4k_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 6, 6, 256)    0           bn4k_branch2a[0][0]
# __________________________________________________________________________________________________
# res4k_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res4k_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 6, 6, 256)    0           bn4k_branch2b[0][0]
# __________________________________________________________________________________________________
# res4k_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res4k_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 6, 6, 1024)   0           bn4k_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 6, 6, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res4l_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res4l_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 6, 6, 256)    0           bn4l_branch2a[0][0]
# __________________________________________________________________________________________________
# res4l_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_40[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res4l_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 6, 6, 256)    0           bn4l_branch2b[0][0]
# __________________________________________________________________________________________________
# res4l_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_41[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res4l_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 1024)   0           bn4l_branch2c[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 6, 6, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res4m_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_42[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res4m_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 6, 6, 256)    0           bn4m_branch2a[0][0]
# __________________________________________________________________________________________________
# res4m_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_43[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res4m_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 6, 6, 256)    0           bn4m_branch2b[0][0]
# __________________________________________________________________________________________________
# res4m_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_44[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res4m_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 1024)   0           bn4m_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 6, 6, 1024)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 3, 3, 512)    524800      activation_45[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 3, 3, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 3, 3, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 3, 3, 2048)   1050624     activation_47[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 3, 3, 2048)   2099200     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 3, 3, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 3, 3, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 3, 3, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 3, 3, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5n_branch2a (Conv2D)         (None, 3, 3, 512)    1049088     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5n_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res5n_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 3, 3, 512)    0           bn5n_branch2a[0][0]
# __________________________________________________________________________________________________
# res5n_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_49[0][0]
# __________________________________________________________________________________________________
# bn5n_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res5n_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 3, 3, 512)    0           bn5n_branch2b[0][0]
# __________________________________________________________________________________________________
# res5n_branch2c (Conv2D)         (None, 3, 3, 2048)   1050624     activation_50[0][0]
# __________________________________________________________________________________________________
# bn5n_branch2c (BatchNormalizati (None, 3, 3, 2048)   8192        res5n_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 3, 3, 2048)   0           bn5n_branch2c[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 3, 3, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# res5o_branch2a (Conv2D)         (None, 3, 3, 512)    1049088     activation_51[0][0]
# __________________________________________________________________________________________________
# bn5o_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res5o_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 3, 3, 512)    0           bn5o_branch2a[0][0]
# __________________________________________________________________________________________________
# res5o_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_52[0][0]
# __________________________________________________________________________________________________
# bn5o_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res5o_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 3, 3, 512)    0           bn5o_branch2b[0][0]
# __________________________________________________________________________________________________
# res5o_branch2c (Conv2D)         (None, 3, 3, 2048)   1050624     activation_53[0][0]
# __________________________________________________________________________________________________
# bn5o_branch2c (BatchNormalizati (None, 3, 3, 2048)   8192        res5o_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 3, 3, 2048)   0           bn5o_branch2c[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 3, 3, 2048)   0           add_17[0][0]
# __________________________________________________________________________________________________
# res5p_branch2a (Conv2D)         (None, 3, 3, 512)    1049088     activation_54[0][0]
# __________________________________________________________________________________________________
# bn5p_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res5p_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 3, 3, 512)    0           bn5p_branch2a[0][0]
# __________________________________________________________________________________________________
# res5p_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# bn5p_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res5p_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 3, 3, 512)    0           bn5p_branch2b[0][0]
# __________________________________________________________________________________________________
# res5p_branch2c (Conv2D)         (None, 3, 3, 2048)   1050624     activation_56[0][0]
# __________________________________________________________________________________________________
# bn5p_branch2c (BatchNormalizati (None, 3, 3, 2048)   8192        res5p_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 3, 3, 2048)   0           bn5p_branch2c[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 3, 3, 2048)   0           add_18[0][0]
# __________________________________________________________________________________________________
# res5q_branch2a (Conv2D)         (None, 3, 3, 512)    1049088     activation_57[0][0]
# __________________________________________________________________________________________________
# bn5q_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res5q_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 3, 3, 512)    0           bn5q_branch2a[0][0]
# __________________________________________________________________________________________________
# res5q_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_58[0][0]
# __________________________________________________________________________________________________
# bn5q_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res5q_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 3, 3, 512)    0           bn5q_branch2b[0][0]
# __________________________________________________________________________________________________
# res5q_branch2c (Conv2D)         (None, 3, 3, 2048)   1050624     activation_59[0][0]
# __________________________________________________________________________________________________
# bn5q_branch2c (BatchNormalizati (None, 3, 3, 2048)   8192        res5q_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 3, 3, 2048)   0           bn5q_branch2c[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 3, 3, 2048)   0           add_19[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_60[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 1)            2049        flatten[0][0]
# ==================================================================================================
# Total params: 31,419,265
# Trainable params: 31,353,857
# Non-trainable params: 65,408
# __________________________________________________________________________________________________

# %%
#hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
#hypermodel.fit(img_train, label_train, epochs=best_epoch, validation_split=0.2)

# %%
'''
TU/e BME Project Imaging 2021
Submission code for Kaggle PCAM
Author: Suzanne Wetstein
'''

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}   
import tensorflow as tf

import numpy as np

import glob
import pandas as pd
from matplotlib.pyplot import imread

from tensorflow.keras.models import model_from_json

#Change these variables to point at the locations and names of the test dataset and your models.
TEST_PATH = r'data/test/' 
MODEL_FILEPATH = r'storage/ResNet_Stage12345_L.json' 
MODEL_WEIGHTS_FILEPATH = r'storage/ResNet_Stage12345_L_weights.hdf5'

# load model and model weights
json_file = open(MODEL_FILEPATH, 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)


# load weights into new model
model.load_weights(MODEL_WEIGHTS_FILEPATH)


# open the test set in batches (as it is a very big dataset) and make predictions
test_files = glob.glob(TEST_PATH + '*')
print(test_files)
submission = pd.DataFrame()

file_batch = 5000
max_idx = len(test_files)

for idx in range(0, max_idx, file_batch):

    print('Indexes: %i - %i'%(idx, idx+file_batch))

    test_df = pd.DataFrame({'path': test_files[idx:idx+file_batch]})


    # get the image id 
    test_df['id'] = test_df.path.map(lambda x: x.split(os.sep)[-1].split('.')[0])
    test_df['image'] = test_df['path'].map(imread)
    
    
    K_test = np.stack(test_df['image'].values)
    
    # apply the same preprocessing as during draining
    K_test = K_test.astype('float')/255.0
    
    predictions = model.predict(K_test)
    
    test_df['label'] = predictions
    submission = pd.concat([submission, test_df[['id', 'label']]])


# save your submission
submission.head()
submission.to_csv('submission_ResNet_Stage12345_L.csv', index = False, header = True)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Indexes: 5000 - 10000
# Indexes: 10000 - 15000
# Indexes: 15000 - 20000
# Indexes: 20000 - 25000
# Indexes: 25000 - 30000
# Indexes: 30000 - 35000
# Indexes: 35000 - 40000
# Indexes: 40000 - 45000
# Indexes: 45000 - 50000
# Indexes: 50000 - 55000
# Indexes: 55000 - 60000
